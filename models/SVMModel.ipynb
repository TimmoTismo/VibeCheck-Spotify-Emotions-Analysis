# %%
# Importing necessary libraries
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import pandas as pd
import math
from numpy import matrix

# %%
#Load variables from BaseModel
# %store -r X_train
# %store -r y_train
# %store -r X_test
# %store -r y_test
# %store -r df

# %%
# Training a linear SVM classifier
from sklearn.svm import SVC
svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train, y_train)
svm_predictions = svm_model_linear.predict(X_test)

# %%
test_y = y_test.to_numpy()
 
print(test_y)
# Out:
# ['Energised' 'Aroused' 'Calm' 'Calm' 'Sad' 'Chill' 'Happy' 'Calm'
#  'Energised' 'Angry' 'Energised' 'Angry' 'Aroused' 'Sleepy' 'Energised'
#  'Calm' 'Sleepy' 'Calm' 'Sad' 'Sleepy' 'Chill' 'Energised' 'Aroused'
#  'Angry' 'Chill' 'Sad' 'Sleepy' 'Chill' 'Calm' 'Sad' 'Chill' 'Sad' 'Chill'
#  'Angry' 'Happy' 'Aroused' 'Chill' 'Chill' 'Chill' 'Angry' 'Sleepy'
#  'Happy' 'Angry' 'Chill' 'Sad' 'Sad' 'Happy' 'Calm' 'Sad' 'Sleepy'
#  'Sleepy' 'Energised' 'Chill' 'Sleepy' 'Energised' 'Angry' 'Happy'
#  'Sleepy' 'Chill' 'Angry' 'Energised' 'Sleepy' 'Sleepy' 'Energised'
#  'Happy' 'Energised' 'Sleepy' 'Chill' 'Energised' 'Sleepy' 'Angry' 'Happy'
#  'Aroused' 'Sad' 'Energised' 'Energised' 'Chill' 'Aroused' 'Happy' 'Angry'
#  'Sleepy' 'Sad' 'Happy' 'Happy' 'Calm' 'Happy' 'Calm' 'Calm' 'Angry'
#  'Sleepy' 'Energised' 'Energised' 'Energised' 'Sad' 'Angry' 'Aroused'
#  'Energised' 'Energised' 'Energised' 'Happy' 'Energised' 'Calm' 'Sad'
# ...

# %%
print(type(svm_predictions))
svm = svm_predictions.tolist()
svm
# Out:
# <class 'numpy.ndarray'>
# ['Energised',
#  'Happy',
#  'Sleepy',
#  'Calm',
#  'Chill',
#  'Aroused',
#  'Happy',
#  'Calm',
#  'Energised',
#  'Angry',
#  'Energised',
#  'Angry',
#  'Happy',
#  'Sleepy',
#  'Energised',
#  'Calm',
#  'Sleepy',
#  'Calm',
#  'Sad',
#  'Sleepy',
#  'Chill',
#  'Energised',
#  'Happy',
#  'Energised',
#  'Chill',
#  'Sad',
#  'Sleepy',
#  'Chill',
#  'Calm',
#  'Chill',
#  'Energised',
#  'Chill',
#  'Chill',
#  'Angry',
#  'Sad',
#  'Chill',
#  'Sad',
#  'Chill',
#  'Happy',
#  'Energised',
#  'Sleepy',
#  'Happy',
#  'Energised',
#  'Chill',
#  'Happy',
#  'Chill',
#  'Energised',
#  'Calm',
#  'Sad',
#  'Sleepy',
#  'Sleepy',
#  'Happy',
#  'Sad',
#  'Sleepy',
#  'Energised',
#  'Energised',
#  'Energised',
#  'Sleepy',
#  'Happy',
#  'Energised',
#  'Energised',
#  'Sleepy',
#  'Sleepy',
#  'Energised',
#  'Chill',
#  'Energised',
#  'Calm',
#  'Sad',
#  'Energised',
#  'Sleepy',
#  'Energised',
#  'Energised',
#  'Sad',
#  'Sad',
#  'Energised',
# ...

# %%
max(svm_predictions)
# Out:
# 'Sleepy'

# %%
# print(similarity[3][5])
def mood(mood):
        
    if mood == 'Happy':
        mood = 0
    elif mood == 'Sad':
        mood = 1
    elif mood == 'Calm':
        mood = 2
    elif mood == 'Sleepy':
        mood = 3
    elif mood == 'Energised':
        mood = 4
    elif mood == 'Aroused':
        mood = 5
    elif mood == 'Angry':
        mood = 6
    elif mood == 'Chill':
        mood = 7
    
    return mood

# %%
def check_similarity(predictions, y_test):
    similarity = [
    [ 1,  0, .5, .3, .5, .7,  0, .6],
    [ 0,  1, .5, .4, .3, .5, .7, .5],
    [.5, .5,  1, .8,  0, .5,  0, .9],
    [.3, .4, .8,  1,  0, .2,  0, .5],
    [.5, .3,  0,  0,  1, .3, .8,  0],
    [.7, .5, .5, .2, .3,  1, .2, .6],
    [ 0, .7,  0,  0, .8, .2,  1,  0],
    [.6, .5, .9, .5,  0, .6,  0,  1]
    ]
    sum_similarity = 0
    test_y = y_test.to_numpy()

    for row in range(len(predictions)):
        model_mood = mood(predictions[row])
        y_mood = mood(test_y[row])
        sum_similarity += similarity[model_mood][y_mood]
    
    accuracy = sum_similarity/len(predictions)
    return accuracy

# %%
# Model accuracy for X_test  
accuracy = svm_model_linear.score(X_test, y_test)
accuracy
# Out:
# 0.5773508594539939

# %%
c_accuracy = check_similarity(svm_predictions, y_test)
c_accuracy
# Out:
# 0.8107178968655204

# %%
# Creating a confusion matrix
cm = confusion_matrix(y_test, svm_predictions)
cm
# Out:
# array([[ 53,   0,   0,   5,  65,   5,   0,   0],
#        [  4,  15,   0,  29,  14,  15,  18,   0],
#        [  0,   0,  83,   3,   1,   0,   0,  16],
#        [  6,   7,   8,  72,  12,  16,  26,   0],
#        [ 27,   3,   2,   6, 123,  10,   0,   0],
#        [  4,   5,   1,  16,  32,  44,   3,   0],
#        [  2,   7,   0,  33,   3,   4,  24,   0],
#        [  0,   0,  10,   0,   0,   0,   0, 157]], dtype=int64)

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, svm_predictions, average=None)
f1
# Out:
# array([0.47321429, 0.22727273, 0.80193237, 0.46302251, 0.58432304,
#        0.44221106, 0.33333333, 0.92352941])

# %%
import pickle

X = df.iloc[:, 2:13] # All rows, features only, no labels
y = df.iloc[:, 13] # All rows, label only, no features

true_clf = SVC(kernel = 'linear', C = 1).fit(X, y)
s = pickle.dump(true_clf, open('model.sav', 'wb'))
